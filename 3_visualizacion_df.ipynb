# %% [markdown]
# # Proyecto Final: Visualización de resultados de datos de supermercados
#
#
# ### 1. Demo Final:
# -Agrupacion de datos y generacion de resultados
# -Visualizar los datos usando la libreria matplotlib

# %%
import pandas as pd #Se importa la libraria de panda

# %%
try:
    venta_por_sku = pd.read_csv("resultados/venta_por_sku.csv", dtype={"UPC":  "string"})
    venta_por_sku.head(1000)
except Exception as e:
       print("Error al momento de cargar el dataframe"+e)
finally:
        print("Se ha cargado el proceso de venta mensual")
venta_por_sku
# Out:
# Se ha cargado el proceso de venta mensual
#             UPC        mean   median         std
# 0   22000002020  317.705887  243.660  229.850825
# 1   22000002037  339.711290  260.405  244.121440
# 2   22000002082  286.894645  198.750  239.681476
# 3   22000006660  323.702268  222.400  246.125769
# 4   22000013194  326.362747  285.920  239.639562
# 5   22000013200  294.864654  231.120  227.665402
# 6   22000013316  314.038022  277.340  251.909437
# 7   22000013392  319.875484  318.550  213.454819
# 8   22000013439  285.602000  199.310  236.120670
# 9   26964726398  256.865147  186.580  211.387249
# 10  30100540861  309.228387  297.990  210.270604
# 11    7.441E+12  373.570645  333.400  216.318203

# %%
try:
    venta_por_tienda = pd.read_csv("resultados/venta_por_tienda.csv")
    venta_por_tienda.head(1000)
except Exception as e:
       print("Error al momento de cargar el dataframe"+e)
finally:
        print("Se ha cargado el proceso de venta mensual")
venta_por_tienda
# Out:
# Se ha cargado el proceso de venta mensual
#                            Pos        mean   median         std
# 0          Super 98 1-Penonome  299.787566  231.465  232.482154
# 1           Super 98 2-Central  291.249630  241.200  228.980620
# 2           Super 98 3-Palermo  329.260828  274.840  249.409294
# 3          Super 98 4- Mercado  295.761597  241.440  205.894366
# 4         Super 98 5- Terminal  306.914516  248.760  239.998858
# 5  Super 98 6- Canto del Llano  290.119035  198.050  235.511001
# 6          Super 98 7- Guarare  337.413158  278.980  249.072493
# 7        Super 98 9-Vista Real  300.567179  258.495  218.026811

# %%
#Se hace ordenamiento por rating de transaccion
venta_por_tienda.set_index("Pos",inplace=True)
venta_por_tienda= venta_por_tienda.sort_values("mean", ascending=False)
venta_por_tienda
# Out:
#                                    mean   median         std
# Pos
# Super 98 7- Guarare          337.413158  278.980  249.072493
# Super 98 3-Palermo           329.260828  274.840  249.409294
# Super 98 5- Terminal         306.914516  248.760  239.998858
# Super 98 9-Vista Real        300.567179  258.495  218.026811
# Super 98 1-Penonome          299.787566  231.465  232.482154
# Super 98 4- Mercado          295.761597  241.440  205.894366
# Super 98 2-Central           291.249630  241.200  228.980620
# Super 98 6- Canto del Llano  290.119035  198.050  235.511001

# %%
#Se hace ordenamiento por rating de transaccion
venta_por_sku.set_index("UPC",inplace=True)
venta_por_sku= venta_por_sku.sort_values("mean", ascending=False)
venta_por_sku
# Out:
#                    mean   median         std
# UPC
# 7.441E+12    373.570645  333.400  216.318203
# 22000002037  339.711290  260.405  244.121440
# 22000013194  326.362747  285.920  239.639562
# 22000006660  323.702268  222.400  246.125769
# 22000013392  319.875484  318.550  213.454819
# 22000002020  317.705887  243.660  229.850825
# 22000013316  314.038022  277.340  251.909437
# 30100540861  309.228387  297.990  210.270604
# 22000013200  294.864654  231.120  227.665402
# 22000002082  286.894645  198.750  239.681476
# 22000013439  285.602000  199.310  236.120670
# 26964726398  256.865147  186.580  211.387249

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
venta_por_tienda.plot(kind='bar');

# %%
# %matplotlib inline
venta_por_sku.plot(kind='bar');
